# %%
import matplotlib.pyplot as plt
import torch
from machinelearning.mdn import MixtureDensityNetwork
from config.experiment_config import ExperimentConfig
from config.plotting_config import PlottingConfig

config = ExperimentConfig()
plotting_config = PlottingConfig()

mdn_path = "results/models/mdn_H2H2v2.pth"

model_dict = torch.load(mdn_path, map_location=torch.device("cpu"))

# Plot loss history
plt.figure(figsize=(10, 5))
plt.plot(model_dict.get("train_loss_history", []), label="Train Loss")
plt.plot(model_dict.get("val_loss_history", []), label="Validation Loss")
plt.xlabel("Epoch", fontsize=plotting_config.label_fontsize)
plt.ylabel("Loss", fontsize=plotting_config.label_fontsize)
plt.legend()
plt.grid()
plt.tight_layout()
plt.savefig("results/plots/H2_loss_history.png", dpi=300)

# %% [markdown]
# ## Histograms

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Check energy conservation

# datafile = "data/H2H2_collisions_numba_b1_0.npy"
# mdn_path = "results/models/H2H2_mdn_b1_0_alpha1_0.pth"
datafile = "data/H2H2_collisions.npy"

if ".npy" in datafile:
    ctc_data = np.load(datafile)
    ctc_data = pd.DataFrame(ctc_data, columns=["Etr", "Er1", "Er2", "Etrp", "Er1p", "Er2p"])
elif ".csv" in datafile:
    ctc_data = pd.read_csv(datafile, skiprows=1)
else:
    raise ValueError("Unsupported file format. Please provide a .csv or .npy file.")

Etot_init = ctc_data.iloc[:,0] + ctc_data.iloc[:,1] + ctc_data.iloc[:,2]
Etot_final = ctc_data.iloc[:,3] + ctc_data.iloc[:,4] + ctc_data.iloc[:,5]
print(f"Total energy before collisions: {Etot_init.sum():.6e} J")
print(f"Total energy after collisions: {Etot_final.sum():.6e} J")
print(f"Total Energy difference: {Etot_final.sum() - Etot_init.sum():.6e} J")
print(f"Relative Energy difference: {100 * (Etot_final.sum() - Etot_init.sum()) / Etot_init.sum():.6e} %")
# Out:
# Total energy before collisions: 2.496830e+08 J
# Total energy after collisions: 2.496795e+08 J
# Total Energy difference: -3.495420e+03 J
# Relative Energy difference: -1.399943e-03 %

# %%
fig, ax= plt.subplots(1, 2, figsize=(12, 5))
# Plot translational energy distribution
bins = np.linspace(0, max(ctc_data.iloc[:,0].max(), ctc_data.iloc[:,3].max()), 50)
Etr_init = ctc_data.iloc[:,0]
Etr_final = ctc_data.iloc[:,3]
ax[0].hist(Etr_init, bins=bins, alpha=0.5, label='Pre-collision $E_{tr}$')
ax[0].hist(Etr_final, bins=bins, alpha=0.5, label='Post-collision $E_{tr}$')
ax[0].set_xlabel('Relativistic Translational temperature (K)')
ax[0].set_ylabel('Frequency')
ax[0].legend()

# Plot rotational energy distribution
bins = np.linspace(0, max(ctc_data.iloc[:,1].max(), ctc_data.iloc[:,4].max()), 50)
Er1_init = ctc_data.iloc[:,1]
Er1_final = ctc_data.iloc[:,4]
ax[1].hist(Er1_init, bins=bins, alpha=0.5, label='Pre-collision $E_{r1}$')
ax[1].hist(Er1_final, bins=bins, alpha=0.5, label='Post-collision $E_{r1}$')
ax[1].set_xlabel('Rotational temperature (K)')
ax[1].set_ylabel('Frequency')
ax[1].legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# This indicates the energy distribution nudges toward equilibrium over many collisions.

# %%
import torch
from utils.helpers import load_dataset
from machinelearning.mdn import MixtureDensityNetwork
from machinelearning.gmm import GaussianMixtureModel
from config.experiment_config import ExperimentConfig
config = ExperimentConfig()

ctc_data = load_dataset(datafile, rows=config.num_samples)

# Sample MDN
mdn = MixtureDensityNetwork(input_dim=config.input_dim, output_dim=config.output_dim, num_mixtures=config.num_mixtures, hidden_dim=config.hidden_dim, randomseed=config.random_seed) 
mdn.load_model(mdn_path)
torch.manual_seed(config.random_seed)
mdn_samples = mdn.sample(x=ctc_data[0])

# Sample GMM
gmm = GaussianMixtureModel(n_components=config.gmm_n_components, covariance_type=config.gmm_covariance_type)
gmm.fit(ctc_data[1])
gmm_samples = gmm.sample(num_samples=config.num_samples)

datasets = {
    "inputs": ctc_data[0][:,1:], # Use only the energy fractions for plotting not the total energy
    "CTC": ctc_data[1],
    "MDN": mdn_samples,
    # "GMM": gmm_samples
}
# Out:
# Dataset contains 30000 rows

# %%
from visualization.plot import plot_density_scatter
from config.plotting_config import PlottingConfig
plotting_config = PlottingConfig()

# get numer of datasets (excluding inputs)
datasetnames = list(datasets.keys())
datasetnames.remove("inputs")
n = len(datasetnames)

# Create scatterplot
figsize_x = plotting_config.figsize[0] * n
figsize_y = plotting_config.figsize[1] * 2
fig, ax = plt.subplots(2, n, figsize=(figsize_x, figsize_y))
plot_density_scatter(ax, datasets=datasets)


eta_labels = [r"$\eta_{tr}$", r"$\eta_{rot,A}$"]
nbins = 30
for i in range(2):
    x = datasets["inputs"][:, i]
    for j, dataset_name in enumerate(datasetnames):
        y = datasets[dataset_name][:, i]

        # Plot diagonal
        ax[i, j].plot([0, 1], [0, 1], 'k--', linewidth=1, label='Diagonal')

        # Bin the x-axis and compute means
        bins = np.linspace(0, 1, nbins)
        bin_indices = np.digitize(x, bins)
        bin_means = np.array([y[bin_indices == k].mean() for k in range(1, len(bins))])
        bin_centers = (bins[:-1] + bins[1:]) / 2

        # Plot a line connecting binned averages
        ax[i, j].plot(bin_centers, bin_means, color='red', label='Average', linewidth=2)
        ax[i, j].legend()

        # Find crossing with diagonal (bin_means - bin_centers changes sign)
        # Filter NaN bins first (empty bins return nan from .mean())
        x_crossings = []
        valid = ~np.isnan(bin_means)
        valid_centers = bin_centers[valid]
        valid_means = bin_means[valid]
        diff = valid_means - valid_centers
        sign_changes = np.where(np.diff(np.sign(diff)))[0]
        for idx in sign_changes:
            x0, x1 = valid_centers[idx], valid_centers[idx + 1]
            d0, d1 = diff[idx], diff[idx + 1]
            x_cross = x0 - d0 * (x1 - x0) / (d1 - d0)
            x_crossings.append(x_cross)

        if x_crossings:
            avg_x_cross = float(np.mean(x_crossings))
            print(f"{dataset_name}, {eta_labels[i]}: average crossover with diagonal at x = {avg_x_cross:.4f}")
        else:
            print(f"{dataset_name}, {eta_labels[i]}: no crossover with diagonal detected")

        ax[i, j].set_xlim(0, 1)
        ax[i, j].set_ylim(0, 1)
plt.tight_layout()
fig.savefig("results/plots/H2_scatter.png", dpi=300)
plt.show()
# Out:
# CTC, $\eta_{tr}$: average crossover with diagonal at x = 0.5799
# MDN, $\eta_{tr}$: average crossover with diagonal at x = 0.5826
# CTC, $\eta_{rot,A}$: average crossover with diagonal at x = 0.4985
# MDN, $\eta_{rot,A}$: average crossover with diagonal at x = 0.4816

# %%
from analysis.kl_divergence import kl_divergence

kl_ctc_mdn_tr  = kl_divergence(datasets["CTC"][:, 0], datasets["MDN"][:, 0])
kl_ctc_mdn_rot = kl_divergence(datasets["CTC"][:, 1], datasets["MDN"][:, 1])

print(f"KL Divergence (eta_tr):    {kl_ctc_mdn_tr:.4f}")
print(f"KL Divergence (eta_rot_A): {kl_ctc_mdn_rot:.4f}")
# Out:
# KL Divergence (eta_tr):    0.0027
# KL Divergence (eta_rot_A): 0.0160

# %%
# Scatterplots for high_tr_frac collisions
fig, ax = plt.subplots(2,2, figsize=(15, 15))

# Plot scatterplots for high_tr_frac collisions
high_tr_frac_mask = datasets["inputs"][:, 0] > 0.8
ctc_high_tr_frac = datasets["CTC"][high_tr_frac_mask]
mdn_high_tr_frac = datasets["MDN"][high_tr_frac_mask]
inputs_high_tr_frac = datasets["inputs"][high_tr_frac_mask]

print(f"Number of high_tr_frac collisions (eta_tr > 0.8): CTC count = {len(ctc_high_tr_frac)} out of {len(datasets['CTC'])}")

ax[0, 0].scatter(inputs_high_tr_frac[:, 0], ctc_high_tr_frac[:, 0], label="CTC", alpha=0.5)
ax[0, 0].set_ylabel(r"$\eta_{tr}'$", fontsize=plotting_config.label_fontsize)
ax[0, 0].set_ylim(0, 1)

ax[1, 0].scatter(inputs_high_tr_frac[:, 1], ctc_high_tr_frac[:, 1], label="CTC", alpha=0.5)
ax[1, 0].set_xlabel(r"$\eta_{rot,A}$", fontsize=plotting_config.label_fontsize)
ax[1, 0].set_ylabel(r"$\eta_{rot,A}'$", fontsize=plotting_config.label_fontsize)
ax[1, 0].set_ylim(0, 1)

ax[0, 1].scatter(inputs_high_tr_frac[:, 0], mdn_high_tr_frac[:, 0], label="MDN", alpha=0.5)
ax[0, 1].set_ylim(0, 1)

ax[1, 1].scatter(inputs_high_tr_frac[:, 1], mdn_high_tr_frac[:, 1], label="MDN", alpha=0.5)
ax[1, 1].set_xlabel(r"$\eta_{rot,A}$", fontsize=plotting_config.label_fontsize)
ax[1, 1].set_ylim(0, 1)

# Compute KL divergence for high_tr_frac collisions
kl_high_tr_frac_mdn_tr  = kl_divergence(ctc_high_tr_frac[:, 0], mdn_high_tr_frac[:, 0])
kl_high_tr_frac_mdn_rot = kl_divergence(ctc_high_tr_frac[:, 1], mdn_high_tr_frac[:, 1])
print(f"KL Divergence for high_tr_frac collisions (eta_tr > 0.8):")
print(f"  KL Divergence (eta_tr):    {kl_high_tr_frac_mdn_tr:.4f}")
print(f"  KL Divergence (eta_rot_A): {kl_high_tr_frac_mdn_rot:.4f}")
# Out:
# Number of high_tr_frac collisions (eta_tr > 0.8): CTC count = 1414 out of 30000
# KL Divergence for high_tr_frac collisions (eta_tr > 0.8):
#   KL Divergence (eta_tr):    0.0125
#   KL Divergence (eta_rot_A): 0.0061

# %%
# Scatterplots for high total energy collisions
fig, ax = plt.subplots(2,2, figsize=(15, 15))
high_e_mask = (ctc_data[0][:,0] > 8000)
ctc_high_e = datasets["CTC"][high_e_mask]
mdn_high_e = datasets["MDN"][high_e_mask]
inputs_high_e = datasets["inputs"][high_e_mask]
print(f"Number of high total energy samples (Etot>8000K) {len(inputs_high_e)} out of {len(high_e_mask)}")

ax[0, 0].scatter(inputs_high_e[:, 0], ctc_high_e[:, 0], label="CTC", alpha=0.5)
ax[0, 0].set_ylabel(r"$\eta_{tr}'$", fontsize=plotting_config.label_fontsize)
ax[0, 0].set_ylim(0, 1)

ax[1, 0].scatter(inputs_high_e[:, 1], ctc_high_e[:, 1], label="CTC", alpha=0.5)
ax[1, 0].set_xlabel(r"$\eta_{rot,A}$", fontsize=plotting_config.label_fontsize)
ax[1, 0].set_ylabel(r"$\eta_{rot,A}'$", fontsize=plotting_config.label_fontsize)
ax[1, 0].set_ylim(0, 1)

ax[0, 1].scatter(inputs_high_e[:, 0], mdn_high_e[:, 0], label="MDN", alpha=0.5)
ax[0, 1].set_ylim(0, 1)

ax[1, 1].scatter(inputs_high_e[:, 1], mdn_high_e[:, 1], label="MDN", alpha=0.5)
ax[1, 1].set_xlabel(r"$\eta_{rot,A}$", fontsize=plotting_config.label_fontsize)
ax[1, 1].set_ylim(0, 1)

# Compute KL divergence for high_tr_frac collisions
kl_high_e_mdn_tr  = kl_divergence(ctc_high_e[:, 0], mdn_high_e[:, 0])
kl_high_e_mdn_rot = kl_divergence(ctc_high_e[:, 1], mdn_high_e[:, 1])
print(f"KL Divergence for high_tr_frac collisions (eta_tr > 0.8):")
print(f"  KL Divergence (eta_tr):    {kl_high_e_mdn_tr:.4f}")
print(f"  KL Divergence (eta_rot_A): {kl_high_e_mdn_rot:.4f}")
# Out:
# Number of high total energy samples (Etot>8000K) 6982 out of 30000
# KL Divergence for high_tr_frac collisions (eta_tr > 0.8):
#   KL Divergence (eta_tr):    0.0051
#   KL Divergence (eta_rot_A): 0.0206
